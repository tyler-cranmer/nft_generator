# %%
from PIL import Image 
from IPython.display import display 
import random
import json

# %%
background = ["Purple"]
background_weights = [100]

avatar = ["Beige", "Chocolate", "Crystalline", "Espresso", "Fair", "Gold", "Honey", "Ivory", "Umber"]
avatar_weights = [15,10,5,10,15,5,15,10,15]

eye = ["Angry Blue", "Angry Gray", "Angry Hazel",
       "Roll Blue", "Roll Green", "Roll Purple",
       "Side Blue", "Side Hazel", "Side Green",
       "Squint Blue", "Squint Green", "Squint Hazel",
       "Teary Blue", "Teary Hazel", "Teary Purple", 'Kali']
eye_weights = [10,10,5,4,5,5,5,5,5,8,6,6,9,9,9,3]

face_prop = ["Face Jewelry", "Face Piercing", "Morrigan Tattoo", "Nose Pierce", "Gold Septum Pierce", "Silver Septum Pierce", "Tribal Tattoo", "Web Tattoo"]
face_prop_weights = [12,12,12,12,12,12,12,16]
 

accessories_god_prop = ["Ankh Bracelet", "Honey Feet", "Celestial Feet", "Wet Feet", "Toe Ring"] 
accessories_god_prop_weights = [20,20,20,20,20]

accessories_prop = ["Ankh Bracelet", "Gold Earings", "Silver Earings", "Toe Ring", "Honey Feet", "Celestial Feet", "Wet Feet"]
accessories_prop_weights = [14,14,16,14,8,10,10]

lips = ["Biting Purple", "Biting Dark Red", "Biting Candy Red", 
        "Gold Fangs Purple", "Gold Fangs Dark Red", "Gold Fangs Candy Red", 
        "Lush Purple", "Lush Dark Red", "Lush Candy Red", 'Aphrodite',
       "Artemis", "Bastet", "Gaia", "Kali", "Morrigan", "Hathor", "Venus"]
lips_weights = [6,6,6,6,6,6,7,6,6,6,6,6,6,6,5,5,5]

hair_color = ['Black', 'Blonde', 'Brunette', 'Teal', 'Pink', 'Purple', 'Red', 'Goddess']
hair_color_weights = [13,13,13,13,13,13,13,9]

blonde_hair = ['Blonde Afro', 'Blonde Round Afro', 'Blonde Blunt Ends',
        'Blonde Braids', 'Blonde Curly Puff', 'Blonde French Braid',
        'Blonde Long Curl', 'Blonde Long Messy', 'Blonde Long Straight',
        'Blonde Short Bangs', 'Blonde Short Curl', 'Blonde Half Back', 'Blonde Short Wavy']

black_hair = ['Black Afro', 'Black Round Afro', 'Black Blunt Ends',
        'Black Braids', 'Black Curly Puff', 'Black French Braid',
        'Black Long Curl', 'Black Long Messy', 'Black Long Straight',
        'Black Short Bangs', 'Black Short Curl', 'Black Half Back', 'Black Short Wavy']

brunette_hair = ['Brunette Afro', 'Brunette Round Afro', 'Brunette Blunt Ends',
        'Brunette Braids', 'Brunette Curly Puff', 'Brunette French Braid',
        'Brunette Long Curl', 'Brunette Long Messy', 'Brunette Long Straight',
        'Brunette Short Bangs', 'Brunette Short Curl', 'Brunette Half Back', 'Brunette Short Wavy']

teal_hair = ['Teal Afro', 'Teal Round Afro', 'Teal Blunt Ends',
        'Teal Braids', 'Teal Curly Puff', 'Teal French Braid',
        'Teal Long Curl', 'Teal Long Messy', 'Teal Long Straight',
        'Teal Short Bangs', 'Teal Short Curl', 'Teal Half Back', 'Teal Short Wavy']

pink_hair = ['Pink Afro', 'Pink Round Afro', 'Pink Blunt Ends',
        'Pink Braids', 'Pink Curly Puff', 'Pink French Braid',
        'Pink Long Curl', 'Pink Long Messy', 'Pink Long Straight',
        'Pink Short Bangs', 'Pink Short Curl', 'Pink Half Back', 'Pink Short Wavy']

purple_hair = ['Purple Afro', 'Purple Round Afro', 'Purple Blunt Ends',
        'Purple Braids', 'Purple Curly Puff', 'Purple French Braid',
        'Purple Long Curl', 'Purple Long Messy', 'Purple Long Straight',
        'Purple Short Bangs', 'Purple Short Curl', 'Purple Half Back', 'Purple Short Wavy']

red_hair =['Red Afro', 'Red Round Afro', 'Red Blunt Ends',
        'Red Braids', 'Red Curly Puff', 'Red French Braid',
        'Red Long Curl', 'Red Long Messy', 'Red Long Straight',
        'Red Short Bangs', 'Red Short Curl', 'Red Half Back', 'Red Short Wavy']

hair_weights = [7,7,3,8,7,11,11,11,10,7,3,7,7]
# hair_weights = [0,0,0,0,0,25,25,25,25,0,0,0,0]

goddess_hair = ['Artemis', 'Bastet', 'Gaia', 'Kali']
goddess_hair_weights = [25,25,25,25]


outfit = ['Amazonian Battle Suit', 'Greek Battle Suit', 'Celestial Corset',
          'Celestial Dress', 'Cowl Neck', 'Cut Out',
          'Deep Cut', 'Hollywood', 'Maimi',
          'Off Shoulder', 'Lingerie', 'Red Sleeve',
          'Sun Dress', 'Chic Bikini', 'Bikini']
outfit_weights = [6,6,6,10,5,5,7,7,5,8,6,6,9,7,7]
# outfit_weights = [25,0,0,25,0,0,0,0,0,0,0,25,25,0,0]

#Used for Long Hair
outfit_2 = ['Amazonian Battle Suit', 'Greek Battle Suit', 'Celestial Corset',
            'Cowl Neck', 'Cut Out','Deep Cut',
            'Hollywood', 'Maimi',
            'Lingerie', 'Red Sleeve','Chic Bikini', 'Bikini']
outfit_2_weights = [7,8,8,8,8,8,8,8,8,7,8,7]

#used for Kali hair
outfit_3 = ['Amazonian Battle Suit', 'Greek Battle Suit', 'Celestial Corset', 'Cowl Neck', 'Cut Out',
          'Deep Cut', 'Hollywood', 'Maimi',
          'Off Shoulder', 'Lingerie', 'Red Sleeve',
          'Sun Dress', 'Chic Bikini', 'Bikini']
outfit_3_weights = [7,7,7,7,7,8,7,7,7,7,7,7,7,8]

#this is for braids 
outfit_4 = ['Amazonian Battle Suit', 'Celestial Corset',
          'Celestial Dress', 'Cowl Neck', 'Cut Out',
          'Deep Cut', 'Hollywood', 'Maimi','Lingerie', 'Red Sleeve',
          'Sun Dress', 'Chic Bikini', 'Bikini']
outfit_4_weights = [6,6,10,6,5,9,10,5,11,6,6,10,10]


nail = ["Blue", "Green", "Purple", "Celestial", "Red Glitter", "White", "Black", "Wine", "Red"]
nail_weights = [12,11,11,11,11,11,11,11,11]


background_files = {
    "Purple": "solid_purple"
}

avatar_files = {
    "Beige": "beige",
    "Chocolate": "chocolate",
    "Crystalline": "crystalline",
    "Espresso": "espresso",
    "Fair": "fair",
    "Gold": "gold",
    "Honey": "honey",
    "Ivory":"ivory",
    "Umber": "umber"
}


eye_files = {
    "Angry Blue": "angry_blue",
    "Angry Gray": "angry_gray",
    "Angry Hazel": "angry_hazel",
    "Roll Blue" : "roll_blue",
    "Roll Green": "roll_green",
    "Roll Purple": "roll_purple",
    "Side Blue": "side_blue",
    "Side Hazel": "side_hazel", 
    "Side Green": "side_green", 
    "Squint Blue": "squint_blue",
    "Squint Green": "squint_green",
    "Squint Hazel": "squint_hazel", 
    "Teary Blue": "teary_blue",
    "Teary Hazel": "teary_hazel",
    "Teary Purple": "teary_purple",
    "Kali": "kali_eyes"
}


face_prop_files = {
    "Face Jewelry": "face_jewelry",
    "Face Piercing": "face_pierce",
    "Morrigan Tattoo": "morrigan_tattoo",
    "Nose Pierce": "septum_pierce",
    "Gold Septum Pierce": "septum_pierce2",
    "Silver Septum Pierce": "septum_pierce3",
    "Tribal Tattoo": "tattoo",
    "Web Tattoo": "tattoo2"
}



accessories_prop_files = {
    "Ankh Bracelet": "ankh_bracelet",
    "Gold Earings": "gold_earing",
    "Silver Earings" : "silver_earing",
    "Honey Feet": "gold_goo",
    "Celestial Feet": "celestial_goo",
    "Wet Feet" : 'wet_goo',
    "Toe Ring": 'toe_ring'
}


lips_files = {
    "Biting Purple": "bit_purple", 
    "Biting Dark Red": "bit_red", 
    "Biting Candy Red": "bit_red2", 
    "Gold Fangs Purple": "fangs_purple",
    "Gold Fangs Dark Red": "fangs_red",
    "Gold Fangs Candy Red": "fangs_red2", 
    "Lush Purple": "lush_lips_purple",
    "Lush Dark Red": "lush_lips_red",
    "Lush Candy Red": "lush_lips_red2", 
    "Aphrodite": "aphrodite",
    "Artemis": "artemis", 
    "Bastet": "bastet", 
    "Gaia": "Gaia", 
    "Kali": "Kali", 
    "Morrigan": "morrigan", 
    "Hathor": "hathor", 
    "Venus": "venus"
}


hair_files = {
    'Blonde Afro': 'blonde/afro_short',
    'Blonde Round Afro': 'blonde/afro',
    'Blonde Blunt Ends': 'blonde/blunt_end',
    'Blonde Braids': 'blonde/braids',
    'Blonde Curly Puff': 'blonde/curly_puff',
    'Blonde French Braid': 'blonde/long_braid',
    'Blonde Long Curl': 'blonde/long_curl',
    'Blonde Long Messy': 'blonde/long_messy',
    'Blonde Long Straight': 'blonde/long_straight',
    'Blonde Short Bangs': 'blonde/short_bangs',
    'Blonde Short Curl': 'blonde/short_curl',
    'Blonde Half Back': 'blonde/short_huhd',
    'Blonde Short Wavy': 'blonde/short_wavy',
    'Black Afro': 'black/afro_short',
    'Black Round Afro': 'black/afro',
    'Black Blunt Ends': 'black/blunt_end',
    'Black Braids': 'black/braids',
    'Black Curly Puff': 'black/curly_puff',
    'Black French Braid': 'black/long_braid',
    'Black Long Curl': 'black/long_curl',
    'Black Long Messy': 'black/long_messy',
    'Black Long Straight': 'black/long_straight',
    'Black Short Bangs': 'black/short_bangs',
    'Black Short Curl': 'black/short_curl',
    'Black Half Back': 'black/short_huhd',
    'Black Short Wavy': 'black/short_wavy',
    'Brunette Afro': 'brunette/afro_short',
    'Brunette Round Afro': 'brunette/afro',
    'Brunette Blunt Ends': 'brunette/blunt_end',
    'Brunette Braids': 'brunette/braids',
    'Brunette Curly Puff': 'brunette/curly_puff',
    'Brunette French Braid': 'brunette/long_braid',
    'Brunette Long Curl': 'brunette/long_curl',
    'Brunette Long Messy': 'brunette/long_messy',
    'Brunette Long Straight': 'brunette/long_straight',
    'Brunette Short Bangs': 'brunette/short_bangs',
    'Brunette Short Curl': 'brunette/short_curl',
    'Brunette Half Back': 'brunette/short_huhd',
    'Brunette Short Wavy': 'brunette/short_wavy',
    'Teal Afro': 'teal/afro_short',
    'Teal Round Afro': 'teal/afro',
    'Teal Blunt Ends': 'teal/blunt_end',
    'Teal Braids': 'teal/braids',
    'Teal Curly Puff': 'teal/curly_puff',
    'Teal French Braid': 'teal/long_braid',
    'Teal Long Curl': 'teal/long_curl',
    'Teal Long Messy': 'teal/long_messy',
    'Teal Long Straight': 'teal/long_straight',
    'Teal Short Bangs': 'teal/short_bangs',
    'Teal Short Curl': 'teal/short_curl',
    'Teal Half Back': 'teal/short_huhd',
    'Teal Short Wavy': 'teal/short_wavy',
    'Pink Afro': 'pink/afro_short',
    'Pink Round Afro': 'pink/afro',
    'Pink Blunt Ends': 'pink/blunt_end',
    'Pink Braids': 'pink/braids',
    'Pink Curly Puff': 'pink/curly_puff',
    'Pink French Braid': 'pink/long_braid',
    'Pink Long Curl': 'pink/long_curl',
    'Pink Long Messy': 'pink/long_messy',
    'Pink Long Straight': 'pink/long_straight',
    'Pink Short Bangs': 'pink/short_bangs',
    'Pink Short Curl': 'pink/short_curl',
    'Pink Half Back': 'pink/short_huhd',
    'Pink Short Wavy': 'pink/short_wavy',
    'Purple Afro': 'purple/afro_short',
    'Purple Round Afro': 'purple/afro',
    'Purple Blunt Ends': 'purple/blunt_end',
    'Purple Braids': 'purple/braids',
    'Purple Curly Puff': 'purple/curly_puff',
    'Purple French Braid': 'purple/long_braid',
    'Purple Long Curl': 'purple/long_curl',
    'Purple Long Messy': 'purple/long_messy',
    'Purple Long Straight': 'purple/long_straight',
    'Purple Short Bangs': 'purple/short_bangs',
    'Purple Short Curl': 'purple/short_curl',
    'Purple Half Back': 'purple/short_huhd',
    'Purple Short Wavy': 'purple/short_wavy',
    'Red Afro': 'red/afro_short',
    'Red Round Afro': 'red/afro',
    'Red Blunt Ends': 'red/blunt_end',
    'Red Braids': 'red/braids',
    'Red Curly Puff': 'red/curly_puff',
    'Red French Braid': 'red/long_braid',
    'Red Long Curl': 'red/long_curl',
    'Red Long Messy': 'red/long_messy',
    'Red Long Straight': 'red/long_straight',
    'Red Short Bangs': 'red/short_bangs',
    'Red Short Curl': 'red/short_curl',
    'Red Half Back': 'red/short_huhd',
    'Red Short Wavy': 'red/short_wavy',
    'Artemis': 'goddess/artemis',
    'Bastet': 'goddess/bastet',
    'Gaia': 'goddess/Gaia',
    'Kali': 'goddess/Kali'
}


outfit_files = {
    'Amazonian Battle Suit': 'amazon_battle',
    'Greek Battle Suit': 'greek_battle',
    'Celestial Corset': 'celestial_corset',
    'Celestial Dress': 'celestial',
    'Cowl Neck': 'cowl_neck',
    'Cut Out': 'cut_out',
    'Deep Cut': 'deep_v',
    'Hollywood': 'hollywood',
    'Maimi': 'miami',
    'Off Shoulder': 'off_shoulder',
    'Lingerie': 'red_lace',
    'Red Sleeve': 'red_sleeve',
    'Sun Dress': 'sun_dress',
    'Chic Bikini': 'swimsuit_vegas',
    'Bikini': 'swimsuit'
    
}

nail_files = {
    "Blue": 'blue',
    "Green": 'green',
    "Purple": 'purple',
    "Celestial": 'celestial',
    "Red Glitter": 'red_glitter',
    "Wine": 'wine',
    "Red": 'red',
    "Black": 'black',
    "White": 'white'
}

# %%
# # Goddess Traits

# god_background = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
# god_avatar = ["Beige", "Chocolate", "Crystalline", "Espresso", "Fair", "Gold", "Honey", "Ivory", "Umber"]
# god_hair = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
# god_eyes = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
# god_lips = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
# god_outfit = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']


# god_files =  {
#     'Aphrodite': 'aphrodite',
#     'Artemis': 'artemis',
#     'Athena': 'athena',
#     'Bastet': 'bastet',
#     'Diana': 'diana',
#     'Gaia': 'gaia',
#     'Hathor': 'hathor',
#     'Hela': 'hela',
#     'Juno': 'juno',
#     'Kali': 'kali',
#     'Lakshmi': 'lakshmi',
#     'Minerva': 'minerva',
#     'Morrigan': 'morrigan',
#     'Pele': 'pele',
#     'Sekmet': 'sekmet',
#     'Venus': 'venus'
# }


# god_avatar_files = {
#     "Beige": "beige",
#     "Chocolate": "chocolate",
#     "Crystalline": "crystalline",
#     "Espresso": "espresso",
#     "Fair": "fair",
#     "Gold": "gold",
#     "Honey": "honey",
#     "Ivory":"ivory",
#     "Umber": "umber",
#     "Blue" : 'blue'
# }

# %%
#GODDESSS TRAIT TABLES

god_background = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
god_avatar = ["Beige", "Chocolate", "Crystalline", "Espresso", "Fair", "Gold", "Honey", "Ivory", "Umber", 'Blue']
god_hair = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
god_eyes = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
god_lips = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']
god_outfit = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']


god_nails = ["Blue", "Green", "Purple", "Celestial", "Red Glitter", "White", "Black", "Wine", "Red"]

god_names = ['Aphrodite', 'Artemis', 'Athena', 'Bastet', 'Diana', 'Gaia', 'Hathor', 'Hela', 'Juno', 'Kali', 'Lakshmi', 'Minerva', 'Morrigan', 'Pele', 'Sekmet', 'Venus']

god_weights = [6,6,6,6,6,6,6,6,6,6,6,6,6,6,6,6]
god_avatar_weights = [10,10,10,10,10,10,10,10,10,10]
god_files =  {
    'Aphrodite': 'aphrodite',
    'Artemis': 'artemis',
    'Athena': 'athena',
    'Bastet': 'bastet',
    'Diana': 'diana',
    'Gaia': 'gaia',
    'Hathor': 'hathor',
    'Hela': 'hela',
    'Juno': 'juno',
    'Kali': 'kali',
    'Lakshmi': 'lakshmi',
    'Minerva': 'minerva',
    'Morrigan': 'morrigan',
    'Pele': 'pele',
    'Sekmet': 'sekmet',
    'Venus': 'venus'
}


goddess_nails_pairs = {
    'Aphrodite': 'Red',
    'Artemis': 'White',
    'Athena': 'Red',
    'Bastet': 'Red',
    'Diana': 'Black',
    'Gaia': 'Red',
    'Hathor': 'Red',
    'Hela': 'Black',
    'Juno': 'Black',
    'Kali': 'Black',
    'Lakshmi': 'Black',
    'Minerva': 'White',
    'Morrigan': 'Wine',
    'Pele': 'White',
    'Sekmet': 'Black',
    'Venus': 'White'
}

god_nails_files = {
    "Blue": 'blue',
    "Green": 'green',
    "Purple": 'purple',
    "Celestial": 'celestial',
    "Red Glitter": 'red_glitter',
    "Wine": 'wine',
    "Red": 'red',
    "White": 'white',
    "Black": 'black'
}



god_avatar_files = {
    "Beige": "beige",
    "Chocolate": "chocolate",
    "Crystalline": "crystalline",
    "Espresso": "espresso",
    "Fair": "fair",
    "Gold": "gold",
    "Honey": "honey",
    "Ivory":"ivory",
    "Umber": "umber",
    "Blue":'blue'
}

god_outfit_files =  {
    'Aphrodite': 'aphrodite',
    'Artemis': 'artemis',
    'Athena': 'athena',
    'Bastet': 'bastet_cat',
    'Diana': 'diana',
    'Gaia': 'gaia',
    'Hathor': 'hathor',
    'Hela': 'hela_skulls',
    'Juno': 'juno',
    'Kali': 'kali',
    'Lakshmi': 'lakshmi',
    'Minerva': 'minerva_owl',
    'Morrigan': 'morrigan_raven',
    'Pele': 'pele',
    'Sekmet': 'sekmet',
    'Venus': 'venus'
}

goddess_body_pairs = {
'Aphrodite' : 'Fair',
'Artemis' : 'Fair',
'Athena': 'Fair',
'Bastet': 'Umber',
'Diana': 'Espresso',
'Gaia': 'Espresso',
'Hathor': 'Espresso',
'Hela': 'Espresso',
'Juno': 'Fair',
'Kali': 'Blue',
'Lakshmi': 'Fair',
'Minerva': 'Fair' ,
'Morrigan': 'Fair',
'Pele': 'Espresso',
'Sekmet': 'Espresso',
'Venus' : 'Fair' 
}

# %%
## Generate Traits

TOTAL_IMAGES = 150 # Number of random unique images we want to generate

all_images = [] 



# A recursive function to generate unique image combinations
def create_new_image():
    
    new_image = {} #
    h_color = random.choices(hair_color, hair_color_weights)[0]

#   For each trait category, select a random trait based on the weightings 
    new_image ["Background"] = random.choices(background, background_weights)[0]
    new_image ["Avatar"] = random.choices(avatar, avatar_weights)[0]
    if h_color == 'Black':
        hair_style_choice = random.choices(black_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]

    elif h_color == 'Blonde':
        hair_style_choice = random.choices(blonde_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]

    elif h_color == 'Brunette':
        hair_style_choice = random.choices(brunette_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]

    elif h_color == 'Teal':
        hair_style_choice = random.choices(teal_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]

    elif h_color == 'Pink':
        hair_style_choice = random.choices(pink_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]

    elif h_color == 'Purple':
        hair_style_choice = random.choices(purple_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]
        
    elif h_color == 'Red':
        hair_style_choice = random.choices(red_hair, hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_prop, accessories_prop_weights)[0]
        
    elif h_color == 'Goddess':
        hair_style_choice = random.choices(goddess_hair, goddess_hair_weights)[0]
        if(hair_style_choice.find('Straight') != -1):
            new_image ["Outfit"] = random.choices(outfit_2, outfit_2_weights)[0]
        elif((hair_style_choice.find('Kali') != -1) or (hair_style_choice.find('French') != -1) or (hair_style_choice.find('Long') != -1)):
            new_image ["Outfit"] = random.choices(outfit_3, outfit_3_weights)[0]
        elif(hair_style_choice.find('Braids') != -1):
            new_image ["Outfit"] = random.choices(outfit_4, outfit_4_weights)[0]
        else: 
            new_image ["Outfit"] = random.choices(outfit, outfit_weights)[0]
        new_image ["Hair"] = hair_style_choice
        new_image ["Eyes"] = random.choices(eye, eye_weights)[0]
        new_image ["Accessories"] = random.choices(accessories_god_prop, accessories_god_prop_weights)[0]
        
    new_image ["Face Jewelry"] = random.choices(face_prop, face_prop_weights)[0]
    new_image ["Lips"] = random.choices(lips, lips_weights)[0]
    new_image ["Nails"] = random.choices(nail, nail_weights)[0]

    
    
    
    if new_image in all_images:
        return create_new_image()
    else:
        return new_image

    
def create_goddess_image():
    new_image = {}
    
    if (len(god_names) != 0): 
        selected_god = random.choices(god_names)[0]
        new_image ["Background"] = selected_god
        new_image ["Avatar"] = goddess_body_pairs[selected_god]
        new_image ["Outfit"] = selected_god
        new_image ["Hair"] = selected_god
        new_image ["Eyes"] = selected_god
        new_image ["Lips"] = selected_god
        new_image ["Nails"] = goddess_nails_pairs[selected_god]
        god_names.pop(god_names.index(selected_god))
    else:
        
        selected_god = random.choices(god_background, god_weights)[0]
        new_image ["Background"] = selected_god
        new_image ["Avatar"] = random.choices(god_avatar, god_avatar_weights)[0]
        new_image ["Outfit"] = selected_god
        new_image ["Hair"] = selected_god
        new_image ["Eyes"] = selected_god
        new_image ["Lips"] = selected_god
        new_image ["Nails"] = random.choices(nail, nail_weights)[0]

    
    if new_image in all_images:
        return create_goddess_image()
    else:
        return new_image
    
    
# Generate the unique combinations based on trait weighting
###############################################################
###############################################################
########### MAKE SURE TO SET MODULO FOR 6969 ##################
###############################################################
###############################################################
for i in range(TOTAL_IMAGES): 
    if i % 4 == 3:
        new_trait_image = create_goddess_image()
    else:
        new_trait_image = create_new_image()
        
    all_images.append(new_trait_image)
    

    
# TESTING PURPOSES    
# for i in range(TOTAL_IMAGES): 

#     new_trait_image = create_new_image()
        
#     all_images.append(new_trait_image)

# %%
# Returns true if all images are unique
def all_images_unique(all_images):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_images)

print("Are all images unique?", all_images_unique(all_images))
# Out:
# Are all images unique? True

# %%
# Add token Id to each image
i = 1
for item in all_images:
    item["tokenId"] = i
    i = i + 1

# %%
print(all_images)
# Out:
# [{'Background': 'Purple', 'Avatar': 'Beige', 'Outfit': 'Deep Cut', 'Hair': 'Brunette Long Straight', 'Eyes': 'Side Green', 'Accessories': 'Celestial Feet', 'Face Jewelry': 'Tattoo', 'Lips': 'Bastet', 'Nails': 'Blue', 'tokenId': 1}, {'Background': 'Purple', 'Avatar': 'Gold', 'Outfit': 'Deep Cut', 'Hair': 'Blonde Long Straight', 'Eyes': 'Side Green', 'Accessories': 'Gold Earings', 'Face Jewelry': 'Face Piercing', 'Lips': 'Venus', 'Nails': 'Red Glitter', 'tokenId': 2}, {'Background': 'Purple', 'Avatar': 'Honey', 'Outfit': 'Lingerie', 'Hair': 'Teal Round Afro', 'Eyes': 'Roll Green', 'Accessories': 'Silver Earings', 'Face Jewelry': 'Nose Pierce', 'Lips': 'Bastet', 'Nails': 'Black', 'tokenId': 3}, {'Background': 'Hathor', 'Avatar': 'Espresso', 'Outfit': 'Hathor', 'Hair': 'Hathor', 'Eyes': 'Hathor', 'Lips': 'Hathor', 'Nails': 'Red', 'tokenId': 4}, {'Background': 'Purple', 'Avatar': 'Espresso', 'Outfit': 'Bikini', 'Hair': 'Purple Short Bangs', 'Eyes': 'Angry Blue', 'Accessories': 'Toe Ring',
# ...

# %%
# Get Trait Counts

background_count = {}
for item in background:
    background_count[item] = 0
    
avatar_count = {}
for item in avatar:
    avatar_count[item] = 0


eye_count = {}
for item in eye:
    eye_count[item] = 0

    
face_prop_count = {}
for item in face_prop:
    face_prop_count[item] = 0
    
lips_count = {}
for item in lips:
    lips_count[item] = 0

    
hair_count = {}
for item in black_hair:
    hair_count[item] = 0
for item in blonde_hair:
    hair_count[item] = 0
for item in brunette_hair:
    hair_count[item]= 0
for item in pink_hair:
    hair_count[item]= 0
for item in purple_hair:
    hair_count[item]= 0
for item in red_hair:
    hair_count[item]= 0
for item in teal_hair:
    hair_count[item]= 0
for item in goddess_hair:
    hair_count[item]= 0
    
outfit_count = {}
for item in outfit:
    outfit_count[item] = 0
    
nail_count = {}
for item in nail:
    nail_count[item] = 0
    
accessories_count = {}
for item in accessories_prop:
    accessories_count[item] = 0
    
    
#### GODDESS TRAIT COUNT ####    
goddess_background_count = {}
for item in god_background:
    goddess_background_count[item] = 0
    
goddess_avatar_count = {}
for item in god_avatar:
    goddess_avatar_count[item] = 0
    
goddess_hair_count = {}
for item in god_hair:
    goddess_hair_count[item]= 0
    
goddess_eye_count = {}
for item in god_eyes:
    goddess_eye_count[item]= 0
    
goddess_lips_count = {}
for item in god_lips:
    goddess_lips_count[item]=0
    
goddess_outfit_count = {}
for item in god_outfit:
    goddess_outfit_count[item] = 0  
    
goddess_nail_count = {}
for item in god_nails:
    goddess_nail_count[item] = 0
    
for image in all_images:
    if(image['Background'] not in god_background):
        background_count[image["Background"]] += 1
        avatar_count[image["Avatar"]] += 1
        eye_count[image["Eyes"]] += 1
        face_prop_count[image["Face Jewelry"]] += 1
        lips_count[image["Lips"]] += 1
        hair_count[image["Hair"]] += 1
        outfit_count[image["Outfit"]] += 1
        nail_count[image["Nails"]] += 1
        accessories_count[image["Accessories"]] += 1
    else:
        goddess_background_count[image["Background"]] += 1
        goddess_avatar_count[image["Avatar"]] += 1
        goddess_eye_count[image["Eyes"]] += 1
        goddess_lips_count[image["Lips"]] += 1
        goddess_hair_count[image["Hair"]] += 1
        goddess_outfit_count[image["Outfit"]] += 1
        goddess_nail_count[image["Nails"]] += 1

print("\n###########################################################################")
print("#################################NORMAL TRAITS###############################")
print("###########################################################################\n")  
print("Background Count = ", background_count)
print("\nAvatar Count = ", avatar_count)
print("\nEye Count = ", eye_count)
print("\nFace Prop Count = ", face_prop_count)
print("\nLips Count =", lips_count)
print("\nHair Count =", hair_count)
print("\nOutfit Count =", outfit_count)
print("\nNail Count =", nail_count)
print("\nAccessories Count =", accessories_count)
print("\n###########################################################################")
print("#################################GODDESS TRAITS###############################")
print("###########################################################################\n")
print("Goddess Background Count = ", goddess_background_count)
print("\nGoddess Avatar Count = ", goddess_avatar_count)
print("\nGoddess Eye Count = ", goddess_eye_count)
print("\nGoddess Lips Count =", goddess_lips_count)
print("\nGoddess Hair Count =", goddess_hair_count)
print("\nGoddess Outfit Count =", goddess_outfit_count)
print("\nNail Count =", goddess_nail_count)
# Out:
# ###########################################################################
# #################################NORMAL TRAITS###############################
# ###########################################################################
#
# Background Count =  {'Purple': 113}
#
# Avatar Count =  {'Beige': 22, 'Chocolate': 10, 'Crystalline': 2, 'Espresso': 13, 'Fair': 15, 'Gold': 7, 'Honey': 20, 'Ivory': 9, 'Umber': 15}
#
# Eye Count =  {'Angry Blue': 7, 'Angry Gray': 9, 'Angry Hazel': 5, 'Roll Blue': 3, 'Roll Green': 7, 'Roll Purple': 8, 'Side Blue': 6, 'Side Hazel': 2, 'Side Green': 10, 'Squint Blue': 10, 'Squint Green': 7, 'Squint Hazel': 10, 'Teary Blue': 7, 'Teary Hazel': 8, 'Teary Purple': 12, 'Kali': 2}
#
# Face Prop Count =  {'Face Jewelry': 14, 'Face Piercing': 9, 'Morrigan Tattoo': 9, 'Nose Pierce': 15, 'Gold Septum Pierce': 13, 'Silver Septum Pierce': 17, 'Tattoo': 18, 'Tattoo2': 18}
#
# ...

# %%
#### Generate Metadata for all Traits 
METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(all_images, outfile, indent=4)

# %%
#### Generate Images    
for item in all_images:
    if(item['Background'] in god_background):
        
        img1 = Image.open(f'./layers/goddesses/background/{god_files[item["Background"]]}.png').convert('RGBA')
        img2 = Image.open(f'./layers/goddesses/avatar/{god_avatar_files[item["Avatar"]]}.png').convert('RGBA')
        img3 = Image.open(f'./layers/goddesses/eyes/{god_files[item["Eyes"]]}.png').convert('RGBA')
        img4 = Image.open(f'./layers/goddesses/lips/{god_files[item["Lips"]]}.png').convert('RGBA')
        img5 = Image.open(f'./layers/goddesses/hair/{god_files[item["Hair"]]}.png').convert('RGBA')
        img6 = Image.open(f'./layers/goddesses/outfit/{god_outfit_files[item["Outfit"]]}.png').convert('RGBA')
        img7 = Image.open(f'./layers/goddesses/nails/{god_nails_files[item["Nails"]]}.png').convert('RGBA')
        
        
        #Create each composite
        com1 = Image.alpha_composite(img1, img2)
        com2 = Image.alpha_composite(com1,img3)
        com3 = Image.alpha_composite(com2, img4)
        com4 = Image.alpha_composite(com3,img5)
        com5 = Image.alpha_composite(com4, img6)
        com6 = Image.alpha_composite(com5, img7)
        
        #Convert to RGB
        rgb_im = com6.convert('RGB')
        file_name = str(item["tokenId"]) + ".png"
        rgb_im.save("./images/" + file_name)
        
    else:
        
        outfit = item["Outfit"]
        bad_outfit = ['Amazonian Battle Suit', 'Celestrial Corset', 'Sun Dress', 'Red Sleeve', 'Off Shoulder', 'Greek Battle Suit', 'Deep Cut']
        hair_style = item['Hair']     
        
        img1 = Image.open(f'./layers/background/{background_files[item["Background"]]}.png').convert('RGBA')
        img2 = Image.open(f'./layers/avatar/{avatar_files[item["Avatar"]]}.png').convert('RGBA')    
        if hair_style.startswith("Blonde"):
            img3 = Image.open(f'./layers/eyes/blonde/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith("Black") or hair_style.startswith("Bastet") or hair_style.startswith("Kali") :
            img3 = Image.open(f'./layers/eyes/black/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith("Brunette") or hair_style.startswith("Artemis") or hair_style.startswith("Gaia"):
            img3 = Image.open(f'./layers/eyes/brunette/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith("Teal"):
            img3 = Image.open(f'./layers/eyes/black/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith('Pink'):
            img3 = Image.open(f'./layers/eyes/black/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith('Purple'):
            img3 = Image.open(f'./layers/eyes/black/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        elif hair_style.startswith('Red'):
            img3 = Image.open(f'./layers/eyes/brunette_light/{eye_files[item["Eyes"]]}.png').convert('RGBA')
        img4 = Image.open(f'./layers/face_props/{face_prop_files[item["Face Jewelry"]]}.png').convert('RGBA')
        img5 = Image.open(f'./layers/nails/{nail_files[item["Nails"]]}.png').convert('RGBA')
        img6 = Image.open(f'./layers/lips/{lips_files[item["Lips"]]}.png').convert('RGBA')
        img7 = Image.open(f'./layers/outfits/{outfit_files[item["Outfit"]]}.png').convert('RGBA')
        img8 = Image.open(f'./layers/hair/{hair_files[item["Hair"]]}.png').convert('RGBA')
        img9 = Image.open(f'./layers/accessories/{accessories_prop_files[item["Accessories"]]}.png').convert('RGBA')

#       Create each composite
        # Changed layering system based on hair attributes and outfits
        if ((hair_style.find('Long') != -1 or hair_style.find('Kali') != -1) and outfit in bad_outfit):
            com1 = Image.alpha_composite(img1, img2)
            com2 = Image.alpha_composite(com1, img3)
            com3 = Image.alpha_composite(com2, img4)
            com4 = Image.alpha_composite(com3, img5)
            com5 = Image.alpha_composite(com4, img6)
            com6 = Image.alpha_composite(com5, img8)
            com7 = Image.alpha_composite(com6, img7)
            com8 = Image.alpha_composite(com7, img9)
            
        else:
        # Normal Layering system
            com1 = Image.alpha_composite(img1, img2)
            com2 = Image.alpha_composite(com1, img3)
            com3 = Image.alpha_composite(com2, img4)
            com4 = Image.alpha_composite(com3, img5)
            com5 = Image.alpha_composite(com4, img6)
            com6 = Image.alpha_composite(com5, img7)
            com7 = Image.alpha_composite(com6, img8)
            com8 = Image.alpha_composite(com7, img9)


        #Convert to RGB
        rgb_im = com8.convert('RGB')
        file_name = str(item["tokenId"]) + ".png"
        rgb_im.save("./images/" + file_name)

# %%
bad_outfit = ['Amazonian Battle Suit', 'Celestrial Corset', 'Sun Dress', 'Red Sleeve']
long_hair = 'Kali'
outfit = 'Red Sleeve'
if ((long_hair.find('Long') != -1 or long_hair.find('Kali') != -1) and outfit in bad_outfit):
    print("yes")
# Out:
# yes

# %%
#### Generate Metadata for each Image    

f = open('./metadata/all-traits.json',) 
data = json.load(f)


IMAGES_BASE_URI = "ipfs://QmRVwsAoAViaSJ8TXLY5W77Ef5kbFmsPqctxrE81kYAnho/" #ipfs://{CID from IPFS}/
PROJECT_NAME = "NFF33T" #NEED TO CHANGE 

def getAttribute(key, value):
    return {
        "trait_type": key,
        "value": value
    }

for i in data:
    if(i["Background"] in god_background):
        token_id = i['tokenId']
        token = {
            "image": IMAGES_BASE_URI + str(token_id) + '.png',
            "tokenId": token_id,
            "name": PROJECT_NAME + ' #' + str(token_id),
            "attributes": []
        }
        token["attributes"].append(getAttribute("Background", i["Background"]))
        token["attributes"].append(getAttribute("Avatar", i["Avatar"]))
        token["attributes"].append(getAttribute("Outfit", i["Outfit"]))
        token["attributes"].append(getAttribute("Hair", i["Hair"]))
        token["attributes"].append(getAttribute("Eyes", i["Eyes"]))
        token["attributes"].append(getAttribute("Lips", i["Lips"]))
        token["attributes"].append(getAttribute("Nails", i["Nails"]))
        
        with open('./metadata/' + str(token_id) + '.json', 'w') as outfile:
            json.dump(token, outfile, indent=4)
    else:
        
        token_id = i['tokenId']
        token = {
            "image": IMAGES_BASE_URI + str(token_id) + '.png',
            "tokenId": token_id,
            "name": PROJECT_NAME + ' #' + str(token_id),
            "attributes": []
        }
        token["attributes"].append(getAttribute("Background", i["Background"]))
        token["attributes"].append(getAttribute("Avatar", i["Avatar"]))
        token["attributes"].append(getAttribute("Eyes", i["Eyes"]))
        token["attributes"].append(getAttribute("Face Jewelry", i["Face Jewelry"]))
        token["attributes"].append(getAttribute("Hair", i["Hair"]))
        token["attributes"].append(getAttribute("Lips", i["Lips"]))
        token["attributes"].append(getAttribute("Outfit", i["Outfit"]))
        token["attributes"].append(getAttribute("Nails", i["Nails"]))
        token["attributes"].append(getAttribute("Accessories", i["Accessories"]))

        with open('./metadata/' + str(token_id) + '.json', 'w') as outfile:
            json.dump(token, outfile, indent=4)
f.close()
